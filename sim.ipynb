# %%
from totoro import Simulator

# %%
sim = Simulator("End2End")
sim.load_sim("testset/test/002.txt")
# Out:
# load graph with 7 nodes and 8 edges with 1000 packets

# %%
sim.reset()
sim.simulate()
# Out:
# packet num: 1000
# sending packet 0 from 1 to 7
# path: [1, 3, 5, 7]
# path: [1, 2, 4, 7]
# path: [1, 6, 7]
# there are 3 paths from 1 to 7
# path {'path': [1, 3, 5, 7], 'success': 0, 'attempt': 0}, cost 0
# path {'path': [1, 2, 4, 7], 'success': 0, 'attempt': 0}, cost 0
# path {'path': [1, 6, 7], 'success': 0, 'attempt': 0}, cost 0
# best path: [1, 3, 5, 7]
# path: 1->3->5->7
# sending packet 1 from 1 to 7
# path {'path': [1, 3, 5, 7], 'success': 0, 'attempt': 1}, cost 1.6006909229441857
# path {'path': [1, 2, 4, 7], 'success': 0, 'attempt': 0}, cost 0
# path {'path': [1, 6, 7], 'success': 0, 'attempt': 0}, cost 0
# best path: [1, 6, 7]
# path: 1->6->7
# sending packet 2 from 1 to 7
# path {'path': [1, 3, 5, 7], 'success': 0, 'attempt': 1}, cost 1.2682622895147087
# path {'path': [1, 2, 4, 7], 'success': 0, 'attempt': 0}, cost 0
# path {'path': [1, 6, 7], 'success': 0, 'attempt': 1}, cost 1.2682622895147087
# best path: [1, 2, 4, 7]
# path: 1->2->4->7
# sending packet 3 from 1 to 7
# ...

# %%
sim = Simulator("Totoro")
sim.load_sim("testset/test/001.txt")
# Out:
# load graph with 39 nodes and 146 edges with 50 packets

# %%
sim.reset()
sim.simulate()
# Out:
# sending packet 0 from 13 to 4
# path: 13->22->7->5->20->11->17->16->23->25->21->31->19->35->38->28->13->22->34->35->26->28->5->28->33->31->4
# sending packet 1 from 13 to 4
# path: 13->28->26->32->33->37->10->3->7->27->37->29->27->32->0->17->32->25->21->31->35->27->15->19->29->9->16->2->1->30->12->31->34->32->23->32->35->34->37->38->4
# sending packet 2 from 13 to 4
# path: 13->22->0->11->6->30->29->36->33->31->4
# sending packet 3 from 13 to 4
# path: 13->4
# sending packet 4 from 13 to 4
# path: 13->4
# sending packet 5 from 13 to 4
# path: 13->4
# sending packet 6 from 13 to 4
# path: 13->4
# sending packet 7 from 13 to 4
# path: 13->28->38->4
# sending packet 8 from 13 to 4
# path: 13->28->4
# sending packet 9 from 13 to 4
# path: 13->27->14->16->2->1->18->19->4
# sending packet 10 from 13 to 4
# path: 13->28->4
# sending packet 11 from 13 to 4
# path: 13->28->4
# sending packet 12 from 13 to 4
# path: 13->4
# sending packet 13 from 13 to 4
# path: 13->4
# ...

# %%
sim = Simulator("Greedy")
sim.load_sim("testset/test/002.txt")
# Out:
# load graph with 7 nodes and 8 edges with 1000 packets

# %%
sim.reset()
sim.simulate()
